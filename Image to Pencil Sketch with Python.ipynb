# %% [markdown]
# # Task-3 Image to Pencil Sketch with Python

# %% [markdown]
# # NAME- MEHUL

# %%
pip install opencv-python
# Out:
# ...
#      |████████████████████████████████| 46.0 MB 4.2 MB/s eta 0:00:012     |█████████████████████▊          | 31.2 MB 4.4 MB/s eta 0:00:04
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import  cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def show(title,img,cmap='RdBu'):
    plt.imshow(img,cmap=cmap)
    plt.title(title)

# %%
image=plt.imread("bunny-rabbit.jpeg")
show("rabbit",image,'RdBu')
#cv2.imshow("rabbit",image)
#cv2.waitKey(0)

# %% [markdown]
# # CONVERT TO GRAYSCALE IMAGE

# %%
gray_image=cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
show("gray_image",gray_image,'gray')
#cv2.imshow("gray_image",gray_image)
#cv2.waitKey(0)

# %% [markdown]
# # invert the grayscale image

# %%
inverted_image =255-gray_image
show("inverted_image",inverted_image,'gray')
#cv2.imshow("inverted_image",inverted_image)
#cv2.waitKey(0)

# %% [markdown]
# # blur the inverted image

# %%
blurred_image =cv2.GaussianBlur(inverted_image,(21,21),0)
show("blurred_image",blurred_image,'gray')
#cv2.imshow("blurred_image",blurred_image)
#cv2.waitKey(0)

# %%
inverted_blurred=255-blurred_image
pencil_sketch=cv2.divide(gray_image,inverted_blurred,scale=256.0)
show("pencil_sketch",pencil_sketch,'gray')

# %% [markdown]
# # if you want to have a look at both the original image and the pencil sketch then we can use the following commands:

# %%
cv2.imshow("rabbit", image)
cv2.imshow("pencil sketch", pencil_sketch)
cv2.waitKey(0)

# %% [markdown]
# image will be displayed in another page

# %% [markdown]
# # THANK YOU
